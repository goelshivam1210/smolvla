# %%
from datasets import load_from_disk
ds = load_from_disk("./data/libero_spatial")
print(ds)
print(ds["train"][0].keys())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from datasets import load_from_disk
# ----> 2 ds = load_from_disk("./data/libero_spatial")
#       3 print(ds)
#       4 print(ds["train"][0].keys())
#
# File ~/Desktop/research/job_2026/ndims/lerobot-venv/lib/python3.12/site-packages/datasets/load.py:1762, in load_from_disk(dataset_path, keep_in_memory, storage_options)
#    1760 fs, *_ = url_to_fs(dataset_path, **(storage_options or {}))
#    1761 if not fs.exists(dataset_path):
# -> 1762     raise FileNotFoundError(f"Directory {dataset_path} not found")
#    1763 if fs.isfile(posixpath.join(dataset_path, config.DATASET_INFO_FILENAME)) and fs.isfile(
#    1764     posixpath.join(dataset_path, config.DATASET_STATE_JSON_FILENAME)
#    1765 ):
# ...
